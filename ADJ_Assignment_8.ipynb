# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('campus_crime.csv')

# %%
data.sort('vehicle', ascending=False)[:20]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-aa21525aeba0> in <module>
# ----> 1 data.sort('vehicle', ascending=False)[:20]
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
data.sort_values('vehicle', ascending=False)[:20]
# Out:
#                                     instname  total_enr  murder  manslaughter  \
# 198     University of New Mexico-Main Campus      28977       0             0
# 130               San Diego State University      30541       0             0
# 189      University of Maryland-College Park      75262       0             0
# 90                        Miami Dade College     509888       0             0
# 173            University of Central Florida     935440       0             0
# 197           University of Nevada-Las Vegas      54728       0             0
# 112                  Oregon State University      24962       0             0
# 13   California State University-Los Angeles      21284       0             0
# 170       University of California-Riverside      20900       0             0
# 182                    University of Houston     119460       0             0
# 206    University of South Carolina-Columbia      30721       0             0
# ...

# %%
#Story Idea 1: I thought vehicle crimes was an interesting category and decided to take a look at the top 20 
#in schools in the category. U of New Mexico's main campus has an extreme outlier so I think it'd be interesting 
#to see if the infrastructure of the school and availability of parking is a contributing factor in these crimes.

# %%
data[data.instname == 'University of Missouri-Columbia']
# Out:
#                             instname  total_enr  murder  manslaughter  \
# 195  University of Missouri-Columbia      33762       0             0
#
#      forcible  nonforce  robbery  agg_aslt  burglary  vehicle  arson
# 195        11         0        1         8        10        1      1

# %%
data.sort_values('total_enr', ascending=False)[:20]
# Out:
#                                               instname  total_enr  murder  \
# 67                           Houston Community College    1323315       0
# 4                    Austin Community College District    1082400       0
# 173                      University of Central Florida     935440       0
# 98                                 New York University     658665       0
# 90                                  Miami Dade College     509888       0
# 120                      Purdue University-Main Campus     449339       0
# 117                             Pima Community College     443628       0
# 8                                      Broward College     379782       0
# 82                            Lone Star College System     378174       0
# 219  Virginia Polytechnic Institute and State Unive...     371232       1
# 208                  University of Southern California     342090       0
# 217                                   Valencia College     341048       0
# ...

# %%
#Story Idea 2: Some of the colleges that are in the list of the top 20 highest enrollments have markedly low crime
#rates. Although some are community colleges, I would look into the percentage of students that take classes on site
# to see how large their online portion of their student population is. If they still have a relatively high number
#of students enrolled that attend classes on campus, the crimes on the campus may be underreported. There may be a 
# fear of police, low staffing problem or faulty reporting system to investigate for a story.

# %%
smaller_data = data[data.total_enr > 50000]

# Highlight Pinellas with facetgrid
g = sns.FacetGrid(smaller_data, size=7)

g.map(plt.scatter, "total_enr", "total_count", alpha=.8)

# %%
#Story Idea 3: This graph gives me an idea of outliers to look at for systemic issues. These institutions are large
#in comparison to lots of thieir counterparts and need to be held accountable for the number of students they are
#serving. I would primarily examine the outliers in the 200,000 range with exceptionally high total counts for crime.
# I would look to see what types of programs they have in place in comparison to those of sim
